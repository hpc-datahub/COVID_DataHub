# %% [markdown]
# # A python code to make the dictionary

# %%
import pandas as pd
import numpy as np
import re

# %%
base = pd.read_csv("base dictionary.csv", engine='python')
base
# Out:
#               variable name  \
# 0                    stfips
# 1                    stname
# 2                   ctyfips
# 3                   ctyname
# 4                    scfips
# ..                      ...
# 225   totalDeathBy_yyyymmdd
# 226     whiteDeath_yyyymmdd
# 227     blackDeath_yyyymmdd
# 228  hispanicDeath_yyyymmdd
# 229     asianDeath_yyyymmdd
#
#                                                  label  \
# 0                                           State name
# 1                                      State FIPS code
# 2                                          County name
# 3                                     County FIPS code
# 4                            FIPS code of state-county
# ..                                                 ...
# 225              Cumulative total covid-19 death count
# 226  Cumulative covid-19 death count for non-Hispan...
# 227  Cumulative covid-19 death count for non-Hispan...
# 228       Cumulative covid-19 death count for Hispanic
# 229  Cumulative covid-19 death count for non-Hispan...
#
#                                                 source  \
# 0    https://www.census.gov/geographies/reference-f...
# 1    https://www.census.gov/geographies/reference-f...
# 2    https://www.census.gov/geographies/reference-f...
# 3    https://www.census.gov/geographies/reference-f...
# 4    https://www.census.gov/geographies/reference-f...
# ..                                                 ...
# 225  https://www.apmresearchlab.org/covid/deaths-by...
# 226  https://www.apmresearchlab.org/covid/deaths-by...
# 227  https://www.apmresearchlab.org/covid/deaths-by...
# 228  https://www.apmresearchlab.org/covid/deaths-by...
# 229  https://www.apmresearchlab.org/covid/deaths-by...
#
#                           file
# 0           casesAndDeaths.csv
# 1           casesAndDeaths.csv
# 2           casesAndDeaths.csv
# 3           casesAndDeaths.csv
# 4           casesAndDeaths.csv
# ..                         ...
# 225  ApmColorOfCoronavirus.csv
# 226  ApmColorOfCoronavirus.csv
# 227  ApmColorOfCoronavirus.csv
# 228  ApmColorOfCoronavirus.csv
# 229  ApmColorOfCoronavirus.csv
#
# [230 rows x 4 columns]

# %% [markdown]
# # Dictionary for cases and deaths

# %%
base_cd = base.loc[base["file"] == "casesAndDeaths.csv"]
base_cd
# Out:
#               variable name                              label  \
# 0                    stfips                         State name
# 1                    stname                    State FIPS code
# 2                   ctyfips                        County name
# 3                   ctyname                   County FIPS code
# 4                    scfips          FIPS code of state-county
# 5  confirmed_cases_yyyymmdd  No of confirmed cases on yyyymmdd
# 6           deaths_yyyymmdd           No of deaths on yyyymmdd
#
#                                               source                file
# 0  https://www.census.gov/geographies/reference-f...  casesAndDeaths.csv
# 1  https://www.census.gov/geographies/reference-f...  casesAndDeaths.csv
# 2  https://www.census.gov/geographies/reference-f...  casesAndDeaths.csv
# 3  https://www.census.gov/geographies/reference-f...  casesAndDeaths.csv
# 4  https://www.census.gov/geographies/reference-f...  casesAndDeaths.csv
# 5         https://github.com/CSSEGISandData/COVID-19  casesAndDeaths.csv
# 6         https://github.com/CSSEGISandData/COVID-19  casesAndDeaths.csv

# %%
df = pd.read_csv("../Pandemic/casesAndDeaths.csv")

d = {'variable name':[] , 'start column': [], 'end column':[], 'start date':[], 'end date': []}

temp_base = base_cd.copy().reset_index(drop = True)
for i in range(temp_base.shape[0]):
    d['variable name'].append(temp_base.loc[i, 'variable name'])
    temp_var = temp_base.loc[i, 'variable name'].replace('_yyyymmdd', '')
    temp_id = [i for i, s in enumerate(df.columns) if temp_var in s]
    if temp_var not in list(base_cd.iloc[0:6, 0]):
        temp_date = [re.findall('20[\d]+', x)[0] for x in df.columns[temp_id]]
    if len(temp_id) > 1:
        d['start column'].append(temp_id[0] + 1)
        d['end column'].append(temp_id[-1] + 1)
        d['start date'].append(temp_date[0])
        d['end date'].append(temp_date[-1])
    else:
        if len(temp_id) == 1:
            d['start column'].append(temp_id[0] + 1)
            d['end column'].append(temp_id[0] + 1)
        else:
            d['start column'].append(-1)
            d['end column'].append(-1)
        d['start date'].append(-1)
        d['end date'].append(-1)

dictionary_casesAndDeaths = pd.DataFrame(d)
dictionary_casesAndDeaths
# Out:
#               variable name  start column  end column start date  end date
# 0                    stfips             1           1         -1        -1
# 1                    stname             2           2         -1        -1
# 2                   ctyfips             3           3         -1        -1
# 3                   ctyname             4           4         -1        -1
# 4                    scfips             5           5         -1        -1
# 5  confirmed_cases_yyyymmdd             6         513   20200122  20210612
# 6           deaths_yyyymmdd           514        1021   20200122  20210612

# %%
dictionary_casesAndDeaths = pd.merge(base_cd, dictionary_casesAndDeaths, on="variable name")
dictionary_casesAndDeaths
# Out:
#               variable name                              label  \
# 0                    stfips                         State name
# 1                    stname                    State FIPS code
# 2                   ctyfips                        County name
# 3                   ctyname                   County FIPS code
# 4                    scfips          FIPS code of state-county
# 5  confirmed_cases_yyyymmdd  No of confirmed cases on yyyymmdd
# 6           deaths_yyyymmdd           No of deaths on yyyymmdd
#
#                                               source                file  \
# 0  https://www.census.gov/geographies/reference-f...  casesAndDeaths.csv
# 1  https://www.census.gov/geographies/reference-f...  casesAndDeaths.csv
# 2  https://www.census.gov/geographies/reference-f...  casesAndDeaths.csv
# 3  https://www.census.gov/geographies/reference-f...  casesAndDeaths.csv
# 4  https://www.census.gov/geographies/reference-f...  casesAndDeaths.csv
# 5         https://github.com/CSSEGISandData/COVID-19  casesAndDeaths.csv
# 6         https://github.com/CSSEGISandData/COVID-19  casesAndDeaths.csv
#
#    start column  end column start date  end date
# 0             1           1         -1        -1
# 1             2           2         -1        -1
# 2             3           3         -1        -1
# 3             4           4         -1        -1
# 4             5           5         -1        -1
# 5             6         513   20200122  20210612
# 6           514        1021   20200122  20210612

# %% [markdown]
# # Dictionary for mobility data

# %%
base_mob = base.loc[base["file"].isin(['mobility_google.csv', 'mobility_unacast.csv', 'mobility_descartes.csv'])]
base_mob
# Out:
#                      variable name  \
# 13                grocery_yyyymmdd
# 14                  parks_yyyymmdd
# 15            residential_yyyymmdd
# 16                 retail_yyyymmdd
# 17                transit_yyyymmdd
# 18              workplace_yyyymmdd
# 19      county_population_yyyymmdd
# 20                  covid_yyyymmdd
# 21    daily_distance_diff_yyyymmdd
# 22  daily_visitation_diff_yyyymmdd
# 23        encounters_rate_yyyymmdd
# 24         grade_distance_yyyymmdd
# 25       grade_encounters_yyyymmdd
# 26            grade_total_yyyymmdd
# 27       grade_visitation_yyyymmdd
# 28           last_updated_yyyymmdd
# 29       n_grade_distance_yyyymmdd
# 30     n_grade_encounters_yyyymmdd
# 31          n_grade_total_yyyymmdd
# 32     n_grade_visitation_yyyymmdd
# 33                weekday_yyyymmdd
# 34                    m50_yyyymmdd
# 35              m50_index_yyyymmdd
# 36                samples_yyyymmdd
#
#                                                 label  \
# 13                  % increase in grocery stores area
# 14                    % increase in parks stores area
# 15              % increase in residential stores area
# 16                   % increase in retail stores area
# 17                  % increase in transit stores area
# 18                % increase in workplace stores area
# 19  The total count of the population for this seg...
# 20  Identifiers whether event date is PRE or POST ...
# 21  Change of average distance traveled from basel...
# 22  Change of visits to non-essential retail and s...
# 23  Rate of unique human encounters per Km² relati...
# 24  A, B, C, D or F score describing county's redu...
# 25  A, B, C, D, or F score describing rate of enco...
# 26  A, A-, B, B-, C, C-, D, D- or F score describi...
# 27  A, B, C, D or F score describing county's redu...
# 28  Timestamp of when this data was processed and ...
# 29  Corresponding number for letter grade where A ...
# 30  Corresponding number for letter grade where A=...
# 31  Corresponding number for letter grade where A ...
# 32  Corresponding number for letter grade where A ...
# 33                                            Weekday
# 34  The median of the max-distance mobility for al...
# 35  The percent of normal m50 in the region, with ...
# 36  The number of samples observed in the specifie...
#
#                                                source                    file
# 13          https://www.google.com/covid19/mobility/      mobility_google.csv
# 14          https://www.google.com/covid19/mobility/      mobility_google.csv
# 15          https://www.google.com/covid19/mobility/      mobility_google.csv
# 16          https://www.google.com/covid19/mobility/      mobility_google.csv
# 17          https://www.google.com/covid19/mobility/      mobility_google.csv
# 18          https://www.google.com/covid19/mobility/      mobility_google.csv
# 19  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 20  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 21  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 22  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 23  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 24  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 25  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 26  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 27  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 28  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 29  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 30  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 31  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 32  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 33  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 34       https://github.com/descarteslabs/DL-COVID-19  mobility_descartes.csv
# 35       https://github.com/descarteslabs/DL-COVID-19  mobility_descartes.csv
# 36       https://github.com/descarteslabs/DL-COVID-19  mobility_descartes.csv

# %%
d = {'variable name':[] , 'start column': [], 'end column':[], 'start date':[], 'end date': []}

for item in ["mobility_google.csv", "mobility_unacast.csv", "mobility_descartes.csv"]:
    df = pd.read_csv("../Pandemic/" + item)
    temp_base = base_mob[base_mob['file'] == item].copy().reset_index(drop = True)
    for i in range(temp_base.shape[0]):
        d['variable name'].append(temp_base.loc[i, 'variable name'])
        temp_var = temp_base.loc[i, 'variable name'].replace('_yyyymmdd', '')
        temp_id = [i for i, s in enumerate(df.columns) if temp_var in s]
        temp_date = [re.findall('20[\d]+', x)[0] for x in df.columns[temp_id]]
        if len(temp_id) > 0:
            d['start column'].append(temp_id[0] + 1)
            d['end column'].append(temp_id[-1] + 1)
            d['start date'].append(temp_date[0])
            d['end date'].append(temp_date[-1])
        else:
            d['start column'].append(-1)
            d['end column'].append(-1)
            d['start date'].append(-1)
            d['end date'].append(-1)
        
dictionary_mobility = pd.DataFrame(d)
dictionary_mobility
# Out:
#                      variable name  start column  end column start date  \
# 0                 grocery_yyyymmdd             7         452   20200215
# 1                   parks_yyyymmdd           453        1344   20200215
# 2             residential_yyyymmdd          1345        2236   20200215
# 3                  retail_yyyymmdd            -1          -1         -1
# 4                 transit_yyyymmdd          2237        2682   20200215
# 5               workplace_yyyymmdd          2683        3574   20200215
# 6       county_population_yyyymmdd             7           7       2018
# 7                   covid_yyyymmdd             8          97   20200224
# 8     daily_distance_diff_yyyymmdd            98         187   20200224
# 9   daily_visitation_diff_yyyymmdd           188         277   20200224
# 10        encounters_rate_yyyymmdd           278         367   20200224
# 11         grade_distance_yyyymmdd           368         907   20200224
# 12       grade_encounters_yyyymmdd           458         997   20200224
# 13            grade_total_yyyymmdd           548        1087   20200224
# 14       grade_visitation_yyyymmdd           638        1177   20200224
# 15           last_updated_yyyymmdd           728         817   20200224
# 16       n_grade_distance_yyyymmdd           818         907   20200224
# 17     n_grade_encounters_yyyymmdd           908         997   20200224
# 18          n_grade_total_yyyymmdd           998        1087   20200224
# 19     n_grade_visitation_yyyymmdd          1088        1177   20200224
# 20                weekday_yyyymmdd          1178        1267   20200224
# 21                    m50_yyyymmdd             7         798   20200301
# 22              m50_index_yyyymmdd           403         798   20200301
# 23                samples_yyyymmdd           799        1194   20200301
#
#     end date
# 0   20210505
# 1   20210505
# 2   20210505
# 3         -1
# 4   20210505
# 5   20210505
# 6       2018
# 7   20200523
# 8   20200523
# 9   20200523
# 10  20200523
# 11  20200523
# 12  20200523
# 13  20200523
# 14  20200523
# 15  20200523
# 16  20200523
# 17  20200523
# 18  20200523
# 19  20200523
# 20  20200523
# 21  20210420
# 22  20210420
# 23  20210420

# %%
# remove the deleted variable in the original data
dictionary_mobility = dictionary_mobility.drop(dictionary_mobility[dictionary_mobility['start column']==-1].index,
                                              axis = 0)
dictionary_mobility
# Out:
#                      variable name  start column  end column start date  \
# 0                 grocery_yyyymmdd             7         452   20200215
# 1                   parks_yyyymmdd           453        1344   20200215
# 2             residential_yyyymmdd          1345        2236   20200215
# 4                 transit_yyyymmdd          2237        2682   20200215
# 5               workplace_yyyymmdd          2683        3574   20200215
# 6       county_population_yyyymmdd             7           7       2018
# 7                   covid_yyyymmdd             8          97   20200224
# 8     daily_distance_diff_yyyymmdd            98         187   20200224
# 9   daily_visitation_diff_yyyymmdd           188         277   20200224
# 10        encounters_rate_yyyymmdd           278         367   20200224
# 11         grade_distance_yyyymmdd           368         907   20200224
# 12       grade_encounters_yyyymmdd           458         997   20200224
# 13            grade_total_yyyymmdd           548        1087   20200224
# 14       grade_visitation_yyyymmdd           638        1177   20200224
# 15           last_updated_yyyymmdd           728         817   20200224
# 16       n_grade_distance_yyyymmdd           818         907   20200224
# 17     n_grade_encounters_yyyymmdd           908         997   20200224
# 18          n_grade_total_yyyymmdd           998        1087   20200224
# 19     n_grade_visitation_yyyymmdd          1088        1177   20200224
# 20                weekday_yyyymmdd          1178        1267   20200224
# 21                    m50_yyyymmdd             7         798   20200301
# 22              m50_index_yyyymmdd           403         798   20200301
# 23                samples_yyyymmdd           799        1194   20200301
#
#     end date
# 0   20210505
# 1   20210505
# 2   20210505
# 4   20210505
# 5   20210505
# 6       2018
# 7   20200523
# 8   20200523
# 9   20200523
# 10  20200523
# 11  20200523
# 12  20200523
# 13  20200523
# 14  20200523
# 15  20200523
# 16  20200523
# 17  20200523
# 18  20200523
# 19  20200523
# 20  20200523
# 21  20210420
# 22  20210420
# 23  20210420

# %%
dictionary_mobility = pd.merge(base_mob, dictionary_mobility, on="variable name")
dictionary_mobility
# Out:
#                      variable name  \
# 0                 grocery_yyyymmdd
# 1                   parks_yyyymmdd
# 2             residential_yyyymmdd
# 3                 transit_yyyymmdd
# 4               workplace_yyyymmdd
# 5       county_population_yyyymmdd
# 6                   covid_yyyymmdd
# 7     daily_distance_diff_yyyymmdd
# 8   daily_visitation_diff_yyyymmdd
# 9         encounters_rate_yyyymmdd
# 10         grade_distance_yyyymmdd
# 11       grade_encounters_yyyymmdd
# 12            grade_total_yyyymmdd
# 13       grade_visitation_yyyymmdd
# 14           last_updated_yyyymmdd
# 15       n_grade_distance_yyyymmdd
# 16     n_grade_encounters_yyyymmdd
# 17          n_grade_total_yyyymmdd
# 18     n_grade_visitation_yyyymmdd
# 19                weekday_yyyymmdd
# 20                    m50_yyyymmdd
# 21              m50_index_yyyymmdd
# 22                samples_yyyymmdd
#
#                                                 label  \
# 0                   % increase in grocery stores area
# 1                     % increase in parks stores area
# 2               % increase in residential stores area
# 3                   % increase in transit stores area
# 4                 % increase in workplace stores area
# 5   The total count of the population for this seg...
# 6   Identifiers whether event date is PRE or POST ...
# 7   Change of average distance traveled from basel...
# 8   Change of visits to non-essential retail and s...
# 9   Rate of unique human encounters per Km² relati...
# 10  A, B, C, D or F score describing county's redu...
# 11  A, B, C, D, or F score describing rate of enco...
# 12  A, A-, B, B-, C, C-, D, D- or F score describi...
# 13  A, B, C, D or F score describing county's redu...
# 14  Timestamp of when this data was processed and ...
# 15  Corresponding number for letter grade where A ...
# 16  Corresponding number for letter grade where A=...
# 17  Corresponding number for letter grade where A ...
# 18  Corresponding number for letter grade where A ...
# 19                                            Weekday
# 20  The median of the max-distance mobility for al...
# 21  The percent of normal m50 in the region, with ...
# 22  The number of samples observed in the specifie...
#
#                                                source                    file  \
# 0           https://www.google.com/covid19/mobility/      mobility_google.csv
# 1           https://www.google.com/covid19/mobility/      mobility_google.csv
# 2           https://www.google.com/covid19/mobility/      mobility_google.csv
# 3           https://www.google.com/covid19/mobility/      mobility_google.csv
# 4           https://www.google.com/covid19/mobility/      mobility_google.csv
# 5   https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 6   https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 7   https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 8   https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 9   https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 10  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 11  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 12  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 13  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 14  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 15  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 16  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 17  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 18  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 19  https://www.unacast.com/covid19/social-distanc...    mobility_unacast.csv
# 20       https://github.com/descarteslabs/DL-COVID-19  mobility_descartes.csv
# 21       https://github.com/descarteslabs/DL-COVID-19  mobility_descartes.csv
# 22       https://github.com/descarteslabs/DL-COVID-19  mobility_descartes.csv
#
#     start column  end column start date  end date
# 0              7         452   20200215  20210505
# 1            453        1344   20200215  20210505
# 2           1345        2236   20200215  20210505
# 3           2237        2682   20200215  20210505
# 4           2683        3574   20200215  20210505
# 5              7           7       2018      2018
# 6              8          97   20200224  20200523
# 7             98         187   20200224  20200523
# 8            188         277   20200224  20200523
# 9            278         367   20200224  20200523
# 10           368         907   20200224  20200523
# 11           458         997   20200224  20200523
# 12           548        1087   20200224  20200523
# 13           638        1177   20200224  20200523
# 14           728         817   20200224  20200523
# 15           818         907   20200224  20200523
# 16           908         997   20200224  20200523
# 17           998        1087   20200224  20200523
# 18          1088        1177   20200224  20200523
# 19          1178        1267   20200224  20200523
# 20             7         798   20200301  20210420
# 21           403         798   20200301  20210420
# 22           799        1194   20200301  20210420

# %% [markdown]
# # Dictionary for medical data
# This needs to be fixed next week [Note on 3/8/2021]

# %%
base_med = base.loc[base["file"].isin(['medical_covidtracking.csv', 'medical_govex.csv'])]
base_med
# Out:
#                          variable name  \
# 43                          FatalityRa
# 44                          Confirmedb
# 45                          DeathsbyPo
# 46                          PCTPOVALL_
# 47                          Unemployme
# ..                                 ...
# 126          positiveIncrease_yyyymmdd
# 127                 recovered_yyyymmdd
# 128                     total_yyyymmdd
# 129          totalTestResults_yyyymmdd
# 130  totalTestResultsIncrease_yyyymmdd
#
#                                                  label  \
# 43                                       Fatality rate
# 44                                            Not sure
# 45                                            Not sure
# 46                                            Not sure
# 47                                   Unemployment rate
# ..                                                 ...
# 126             Increase in positive cases on that day
# 127                          People who have recovered
# 128  DEPRECATED Will be removed in the future. (pos...
# 129  Calculated value (positive + negative) of tota...
# 130  Total increase in number of test results on th...
#
#                                  source                       file
# 43   https://coronavirus.jhu.edu/us-map          medical_govex.csv
# 44   https://coronavirus.jhu.edu/us-map          medical_govex.csv
# 45   https://coronavirus.jhu.edu/us-map          medical_govex.csv
# 46   https://coronavirus.jhu.edu/us-map          medical_govex.csv
# 47   https://coronavirus.jhu.edu/us-map          medical_govex.csv
# ..                                  ...                        ...
# 126       https://covidtracking.com/api  medical_covidtracking.csv
# 127       https://covidtracking.com/api  medical_covidtracking.csv
# 128       https://covidtracking.com/api  medical_covidtracking.csv
# 129       https://covidtracking.com/api  medical_covidtracking.csv
# 130       https://covidtracking.com/api  medical_covidtracking.csv
#
# [88 rows x 4 columns]

# %%
d = {'variable name':[] , 'start column': [], 'end column':[], 'start date':[], 'end date': []}

for item in ['medical_covidtracking.csv', 'medical_govex.csv']:
    df = pd.read_csv("../Pandemic/" + item)
    temp_base = base_med[base_med['file'] == item].copy().reset_index(drop = True)
    for i in range(temp_base.shape[0]):
        d['variable name'].append(temp_base.loc[i, 'variable name'])
        temp_var = temp_base.loc[i, 'variable name'].replace('_yyyymmdd', '')
        temp_id = [i for i, s in enumerate(df.columns) if temp_var in s]
        temp_date = [re.findall('20[\d]+', x) for x in df.columns[temp_id]]
        if len(temp_date[0]) != 0:
            temp_date = [x[0] for x in temp_date]
        else:
            temp_date = [-1]
        if len(temp_id) > 0:
            d['start column'].append(temp_id[0] + 1)
            d['end column'].append(temp_id[-1] + 1)
            d['start date'].append(temp_date[0])
            d['end date'].append(temp_date[-1])
        else:
            d['start column'].append(-1)
            d['end column'].append(-1)
            d['start date'].append(-1)
            d['end date'].append(-1)
        
dictionary_medical = pd.DataFrame(d)
dictionary_medical
# Out:
# /Users/xywu/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1683,1684,1685,1686,1687,1688,1689,1690,1691,5508,5509,5928,5929,6348,6349,8028,8029,19323,19324,19325,19326,19327,19328,19329,19330,19331) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                 variable name  start column  end column start date  end date
# 0   dataQualityGrade_yyyymmdd         18064       18483   20200113  20210307
# 1        dateChecked_yyyymmdd          7984        8403   20200113  20210307
# 2              death_yyyymmdd          6724       18903   20200113  20210307
# 3      deathIncrease_yyyymmdd         18484       18903   20200113  20210307
# 4               hash_yyyymmdd         19324       19743   20200113  20210307
# ..                        ...           ...         ...        ...       ...
# 83                    NonHisp            46          67         -1        -1
# 84                  Age_35_64            68          68         -1        -1
# 85                  Age_65_74            69          69         -1        -1
# 86                Shape__Area            93          93         -1        -1
# 87              Shape__Length            94          94         -1        -1
#
# [88 rows x 5 columns]

# %%
dictionary_medical = pd.merge(base_med, dictionary_medical, on="variable name", how='outer')
dictionary_medical.to_csv("med_dict_temp.csv")
dictionary_medical
# Out:
#                         variable name  \
# 0                          FatalityRa
# 1                          Confirmedb
# 2                          DeathsbyPo
# 3                          PCTPOVALL_
# 4                          Unemployme
# ..                                ...
# 83          positiveIncrease_yyyymmdd
# 84                 recovered_yyyymmdd
# 85                     total_yyyymmdd
# 86          totalTestResults_yyyymmdd
# 87  totalTestResultsIncrease_yyyymmdd
#
#                                                 label  \
# 0                                       Fatality rate
# 1                                            Not sure
# 2                                            Not sure
# 3                                            Not sure
# 4                                   Unemployment rate
# ..                                                ...
# 83             Increase in positive cases on that day
# 84                          People who have recovered
# 85  DEPRECATED Will be removed in the future. (pos...
# 86  Calculated value (positive + negative) of tota...
# 87  Total increase in number of test results on th...
#
#                                 source                       file  \
# 0   https://coronavirus.jhu.edu/us-map          medical_govex.csv
# 1   https://coronavirus.jhu.edu/us-map          medical_govex.csv
# 2   https://coronavirus.jhu.edu/us-map          medical_govex.csv
# 3   https://coronavirus.jhu.edu/us-map          medical_govex.csv
# 4   https://coronavirus.jhu.edu/us-map          medical_govex.csv
# ..                                 ...                        ...
# 83       https://covidtracking.com/api  medical_covidtracking.csv
# 84       https://covidtracking.com/api  medical_covidtracking.csv
# 85       https://covidtracking.com/api  medical_covidtracking.csv
# 86       https://covidtracking.com/api  medical_covidtracking.csv
# 87       https://covidtracking.com/api  medical_covidtracking.csv
#
#     start column  end column start date  end date
# 0              8           8         -1        -1
# 1              9           9         -1        -1
# 2             10          10         -1        -1
# 3             11          11         -1        -1
# 4             12          12         -1        -1
# ..           ...         ...        ...       ...
# 83         15964       16383   20200113  20210307
# 84          5044        5463   20200113  20210307
# 85          1684       17643   20200113  20210307
# 86          1684       17643   20200113  20210307
# 87         17224       17643   20200113  20210307
#
# [88 rows x 8 columns]

# %% [markdown]
# # Dictionary for policy data

# %%
base_policy = base.loc[base["file"] == "policy.csv"]
base_policy
# Out:
#                                          variable name  \
# 131                                         Unnamed: 0
# 132                                             stfips
# 133                                             stname
# 134                                            ctyfips
# 135                                            ctyname
# ..                                                 ...
# 199  Proof of work eligibility requirement for vacc...
# 200  Proof of age eligibility requirement for vacci...
# 201     Proof of residency requirement for vaccination
# 202  Penalty for failure to comply with vaccine dis...
# 203  Expanded scope of practice of certain health p...
#
#                                                  label  \
# 131                                         Row number
# 132                                         State name
# 133                                    State FIPS code
# 134                                        County name
# 135                                   County FIPS code
# ..                                                 ...
# 199  Proof of work eligibility requirement for vacc...
# 200  Proof of age eligibility requirement for vacci...
# 201     Proof of residency requirement for vaccination
# 202  Penalty for failure to comply with vaccine dis...
# 203  Expanded scope of practice of certain health p...
#
#                                                 source        file
# 131                                                NaN  policy.csv
# 132  https://www.census.gov/geographies/reference-f...  policy.csv
# 133  https://www.census.gov/geographies/reference-f...  policy.csv
# 134  https://www.census.gov/geographies/reference-f...  policy.csv
# 135  https://www.census.gov/geographies/reference-f...  policy.csv
# ..                                                 ...         ...
# 199  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 200  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 201  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 202  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 203  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
#
# [73 rows x 4 columns]

# %%
dict = {"variable name":[] , "start column": [], "end column":[], "start date":[], "end date": []}
dictionary = pd.DataFrame(dict)
dictionary

df = pd.read_csv("../Pandemic/policy.csv")
name = []
start = []
end = []

start_date = []
end_date = []

file = []

ct = 0

for col in df.columns:
    if col.split("_")[:-1] == []:
        name.append(col)
        start.append(df.columns.get_loc(col))
        start_date.append("")
        file.append("policy.csv")
        if ct != 0:
            end.append(df.columns.get_loc(col) -1) 
            end_date.append("")
    else:       
        new = ("_".join(col.split("_")[:-1])) + "_yyyymmdd"
        
        if new not in name:
            name.append(new)
            start.append(df.columns.get_loc(col))
            start_date.append(col.split("_")[-1])
            file.append("policy.csv")
            if ct != 0:
                end.append(df.columns.get_loc(col) -1) 
                end_date.append(df.columns[df.columns.get_loc(col) -1].split("_")[-1])
    ct = ct+1

end.append(len(df.columns) -1)
end_date.append(df.columns[-1].split("_")[-1])

dictionary["variable name"] = name
dictionary["start column"] = start
dictionary["end column"] = end
dictionary["start date"] = start_date
dictionary["end date"] = end_date

for i in range(dictionary.shape[0]):
    if isinstance(dictionary.iloc[i, 3], str) == True:
        if dictionary.iloc[i, 3].isnumeric() == False:
            dictionary.iloc[i, 3] = ""
    if isinstance(dictionary.iloc[i, 4], str) == True:
        if dictionary.iloc[i, 4].isnumeric() == False:
            dictionary.iloc[i, 4] = ""


dictionary_policy = dictionary
dictionary_policy
# Out:
#                                      variable name  start column  end column  \
# 0                                           stname             0           0
# 1                                           stfips             1           1
# 2                                           stabbr             2           2
# 3                      Restriction details include             3           3
# 4           Statewide mandated stay at home order?             4           4
# ..                                             ...           ...         ...
# 249                        Sep 1 2020 Minimum Wage           249         249
# 250                        Oct 1 2020 Minimum Wage           250         250
# 251           2020 Minimum Wage for Tipped Workers           251         251
# 252                              2021 Minimum Wage           252         252
# 253  Different Minimum Wage for Smaller Businesses           253         253
#
#     start date end date
# 0
# 1
# 2
# 3
# 4
# ..         ...      ...
# 249
# 250
# 251
# 252
# 253
#
# [254 rows x 5 columns]

# %%
dictionary_policy = pd.merge(base_policy, dictionary_policy, on="variable name")
dictionary_policy
# Out:
#                                         variable name  \
# 0                                              stfips
# 1                                              stname
# 2                         Restriction details include
# 3              Statewide mandated stay at home order?
# 4                             Urgency of restrictions
# 5    Effective date of executive restriction detailed
# 6                                    Closed day cares
# 7               Date banned visitors to nursing homes
# 8                      Stay at home/ shelter in place
# 9             End/relax stay at home/shelter in place
# 10                 Closed restaurants except take out
# 11                                 Reopen restaurants
# 12                                        Closed gyms
# 13                              Closed movie theaters
# 14                            Reopened movie theaters
# 15  Modify Medicaid requirements with 1135 waivers...
# 16  Reopened ACA enrollment using a special enroll...
# 17                        Allow audio-only telehealth
# 18                Resumed elective medical procedures
# 19  Waived one week waiting period for unemploymen...
# 20                                    Paid sick leave
# 21  Vaccine allocation phase: Frontline Healthcare...
# 22  Vaccine allocation phase: Healthcare Service W...
# 23  Vaccine allocation phase: Home Healthcare Workers
# 24  Vaccine allocation phase: Additional Healthcar...
# 25  Vaccine allocation phase: Long-term Care Resid...
# 26            Vaccine allocation phase: EMS Providers
# 27             Vaccine allocation phase: Firefighters
# 28  Vaccine allocation phase: Law Enforcement & Pu...
# 29       Vaccine allocation phase: Correctional Staff
# 30          Vaccine allocation phase: Adults Ages 75+
# 31          Vaccine allocation phase: Adults Ages 65+
# 32  Vaccine allocation phase: Adults w/ High-Risk ...
# 33  Vaccine allocation phase: Pre-K-12 School Empl...
# 34  Vaccine allocation phase: Higher Education Emp...
# 35   Vaccine allocation phase: Public Transit Workers
# 36      Vaccine allocation phase: Food Supply Workers
# 37    Vaccine allocation phase: Grocery Store Workers
# 38  Vaccine allocation phase: Frontline Essential ...
# 39  Vaccine allocation phase: Additional Essential...
# 40           Vaccine allocation phase: General Public
# 41  Proof of work eligibility requirement for vacc...
# 42  Proof of age eligibility requirement for vacci...
# 43     Proof of residency requirement for vaccination
# 44  Penalty for failure to comply with vaccine dis...
# 45  Expanded scope of practice of certain health p...
#
#                                                 label  \
# 0                                          State name
# 1                                     State FIPS code
# 2                          Details about restrictions
# 3           Has the state mandated stay at home order
# 4                     How urgent are the restrictions
# 5                Date of emergency policy into effect
# 6                       Date when daycare were closed
# 7         Date when nursing home visitors were banned
# 8                 Date when stay at home was declared
# 9                                                 NaN
# 10                             Are restaurants closed
# 11                            When restaurants reopen
# 12                                    Are gyms closed
# 13                          Are movie theatres closed
# 14                   When movie theatres are reopened
# 15  Modify Medicaid requirements with 1135 waivers...
# 16  Reopened ACA enrollment using a special enroll...
# 17                        Allow audio-only telehealth
# 18                Resumed elective medical procedures
# 19  Waived one week waiting period for unemploymen...
# 20                         Is Paid sick leave present
# 21  Vaccine allocation phase: Frontline Healthcare...
# 22  Vaccine allocation phase: Healthcare Service W...
# 23  Vaccine allocation phase: Home Healthcare Workers
# 24  Vaccine allocation phase: Additional Healthcar...
# 25  Vaccine allocation phase: Long-term Care Resid...
# 26            Vaccine allocation phase: EMS Providers
# 27             Vaccine allocation phase: Firefighters
# 28  Vaccine allocation phase: Law Enforcement & Pu...
# 29       Vaccine allocation phase: Correctional Staff
# 30          Vaccine allocation phase: Adults Ages 75+
# 31          Vaccine allocation phase: Adults Ages 65+
# 32  Vaccine allocation phase: Adults w/ High-Risk ...
# 33  Vaccine allocation phase: Pre-K-12 School Empl...
# 34  Vaccine allocation phase: Higher Education Emp...
# 35   Vaccine allocation phase: Public Transit Workers
# 36      Vaccine allocation phase: Food Supply Workers
# 37    Vaccine allocation phase: Grocery Store Workers
# 38  Vaccine allocation phase: Frontline Essential ...
# 39  Vaccine allocation phase: Additional Essential...
# 40           Vaccine allocation phase: General Public
# 41  Proof of work eligibility requirement for vacc...
# 42  Proof of age eligibility requirement for vacci...
# 43     Proof of residency requirement for vaccination
# 44  Penalty for failure to comply with vaccine dis...
# 45  Expanded scope of practice of certain health p...
#
#                                                source        file  \
# 0   https://www.census.gov/geographies/reference-f...  policy.csv
# 1   https://www.census.gov/geographies/reference-f...  policy.csv
# 2   https://github.com/govex/COVID-19/tree/master/...  policy.csv
# 3   https://github.com/govex/COVID-19/tree/master/...  policy.csv
# 4   https://github.com/govex/COVID-19/tree/master/...  policy.csv
# 5   https://github.com/govex/COVID-19/tree/master/...  policy.csv
# 6   https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 7   https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 8   https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 9   https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 10  https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 11  https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 12  https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 13  https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 14  https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 15  https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 16  https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 17  https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 18  https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 19  https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 20  https://www.bu.edu/sph/2020/04/01/tracking-cov...  policy.csv
# 21  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 22  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 23  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 24  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 25  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 26  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 27  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 28  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 29  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 30  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 31  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 32  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 33  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 34  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 35  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 36  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 37  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 38  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 39  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 40  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 41  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 42  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 43  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 44  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
# 45  https://www.bu.edu/sph/news/articles/2020/trac...  policy.csv
#
#     start column  end column start date end date
# 0              1           1
# 1              0           0
# 2              3           3
# 3              4           4
# 4              5           5
# 5              6           6
# 6             10          10
# 7             12          12
# 8             13          13
# 9             15          15
# 10            33          33
# 11            34          34
# 12            36          36
# 13            38          38
# 14            39          39
# 15           149         149
# 16           150         150
# 17           152         152
# 18           176         176
# 19           181         181
# 20           219         219
# 21            64          64
# 22            65          65
# 23            66          66
# 24            67          67
# 25            68          68
# 26            69          69
# 27            70          70
# 28            71          71
# 29            72          72
# 30            75          75
# 31            76          76
# 32            77          77
# 33            78          78
# 34            79          79
# 35            80          80
# 36            81          81
# 37            82          82
# 38            83          83
# 39            84          84
# 40            85          85
# 41           100         100
# 42           101         101
# 43           102         102
# 44           103         103
# 45           104         104

# %% [markdown]
# # Dictionary for vaccine data

# %%
base_vaccine = base.loc[base["file"] == "vaccine_allocation.csv"]
base_vaccine
# Out:
#                                          variable name  \
# 204                                       jurisdiction
# 205  no_pfizer_because_ultra_cold_requirement_yyyymmdd
# 206                   pfizer_allocation_dose1_yyyymmdd
# 207                   pfizer_allocation_dose2_yyyymmdd
# 208  pfizer_receive_dose1_dose2_simultaneously_yyyy...
# 209        pfizer_sovereign_nation_supplement_yyyymmdd
# 210                  moderna_allocation_dose1_yyyymmdd
# 211                  moderna_allocation_dose2_yyyymmdd
# 212  moderna_receive_dose1_dose2_simultaneously_yyy...
# 213       moderna_sovereign_nation_supplement_yyyymmdd
# 214                  janssen_allocation_dose1_yyyymmdd
# 215         janssen_receive_dose1_dose2_simultaneously
# 216                janssen_sovereign_nation_supplement
#
#                                                  label  \
# 204                                       Jurisdiction
# 205           No pfizer because ultra-cold requirement
# 206                Pfizer: weekly allocation of dose 1
# 207                Pfizer: weekly allocation of dose 2
# 208   Pfizer: receive dose 1 and dose 2 simultaneously
# 209        Pfizer: Sovereign Nation Supplement Project
# 210               Moderna: weekly allocation of dose 1
# 211               Moderna: weekly allocation of dose 2
# 212  Moderna: receive dose 1 and dose 2 simultaneously
# 213       Moderna: Sovereign Nation Supplement Project
# 214                  Janssen: weekly allocation dose 1
# 215  Janssen: receive dose 1 and dose 2 simultaneously
# 216       Janssen: Sovereign Nation Supplement Project
#
#                                                 source                    file
# 204  https://data.cdc.gov/Vaccinations/COVID-19-Vac...  vaccine_allocation.csv
# 205  https://data.cdc.gov/Vaccinations/COVID-19-Vac...  vaccine_allocation.csv
# 206  https://data.cdc.gov/Vaccinations/COVID-19-Vac...  vaccine_allocation.csv
# 207  https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 208  https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 209  https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 210  https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 211  https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 212  https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 213  https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 214  https://data.cdc.gov/Vaccinations/COVID-19-Vac...  vaccine_allocation.csv
# 215  https://data.cdc.gov/Vaccinations/COVID-19-Vac...  vaccine_allocation.csv
# 216  https://data.cdc.gov/Vaccinations/COVID-19-Vac...  vaccine_allocation.csv

# %%
df = pd.read_csv("../Pandemic/vaccine_allocation.csv")

d = {'variable name':[] , 'start column': [], 'end column':[], 'start date':[], 'end date': []}

temp_base = base_vaccine.copy().reset_index(drop = True)
for i in range(temp_base.shape[0]):
    d['variable name'].append(temp_base.loc[i, 'variable name'])
    temp_var = temp_base.loc[i, 'variable name'].replace('_yyyymmdd', '')
    temp_id = [i for i, s in enumerate(df.columns) if temp_var in s]
    if temp_var != 'jurisdiction':
        temp_date = [re.findall('20[\d]+', x)[0] for x in df.columns[temp_id]]
    if len(temp_id) > 1:
        d['start column'].append(temp_id[0] + 1)
        d['end column'].append(temp_id[-1] + 1)
        d['start date'].append(temp_date[0])
        d['end date'].append(temp_date[-1])
    else:
        if len(temp_id) == 1:
            d['start column'].append(temp_id[0] + 1)
            d['end column'].append(temp_id[0] + 1)
        else:
            d['start column'].append(-1)
            d['end column'].append(-1)
        d['start date'].append(-1)
        d['end date'].append(-1)

dictionary_vaccine = pd.DataFrame(d)
dictionary_vaccine
# Out:
#                                         variable name  start column  \
# 0                                        jurisdiction             4
# 1   no_pfizer_because_ultra_cold_requirement_yyyymmdd             5
# 2                    pfizer_allocation_dose1_yyyymmdd            32
# 3                    pfizer_allocation_dose2_yyyymmdd            59
# 4   pfizer_receive_dose1_dose2_simultaneously_yyyy...            86
# 5         pfizer_sovereign_nation_supplement_yyyymmdd           113
# 6                   moderna_allocation_dose1_yyyymmdd           140
# 7                   moderna_allocation_dose2_yyyymmdd           166
# 8   moderna_receive_dose1_dose2_simultaneously_yyy...           192
# 9        moderna_sovereign_nation_supplement_yyyymmdd           218
# 10                  janssen_allocation_dose1_yyyymmdd           244
# 11         janssen_receive_dose1_dose2_simultaneously           252
# 12                janssen_sovereign_nation_supplement           260
#
#     end column start date  end date
# 0            4         -1        -1
# 1           31   20201214  20210614
# 2           58   20201214  20210614
# 3           85   20201214  20210614
# 4          112   20201214  20210614
# 5          139   20201214  20210614
# 6          165   20201221  20210614
# 7          191   20201221  20210614
# 8          217   20201221  20210614
# 9          243   20201221  20210614
# 10         251   20210301  20210510
# 11         259   20210301  20210510
# 12         267   20210301  20210510

# %%
dictionary_vaccine = pd.merge(base_vaccine, dictionary_vaccine, on="variable name")
dictionary_vaccine
# Out:
#                                         variable name  \
# 0                                        jurisdiction
# 1   no_pfizer_because_ultra_cold_requirement_yyyymmdd
# 2                    pfizer_allocation_dose1_yyyymmdd
# 3                    pfizer_allocation_dose2_yyyymmdd
# 4   pfizer_receive_dose1_dose2_simultaneously_yyyy...
# 5         pfizer_sovereign_nation_supplement_yyyymmdd
# 6                   moderna_allocation_dose1_yyyymmdd
# 7                   moderna_allocation_dose2_yyyymmdd
# 8   moderna_receive_dose1_dose2_simultaneously_yyy...
# 9        moderna_sovereign_nation_supplement_yyyymmdd
# 10                  janssen_allocation_dose1_yyyymmdd
# 11         janssen_receive_dose1_dose2_simultaneously
# 12                janssen_sovereign_nation_supplement
#
#                                                 label  \
# 0                                        Jurisdiction
# 1            No pfizer because ultra-cold requirement
# 2                 Pfizer: weekly allocation of dose 1
# 3                 Pfizer: weekly allocation of dose 2
# 4    Pfizer: receive dose 1 and dose 2 simultaneously
# 5         Pfizer: Sovereign Nation Supplement Project
# 6                Moderna: weekly allocation of dose 1
# 7                Moderna: weekly allocation of dose 2
# 8   Moderna: receive dose 1 and dose 2 simultaneously
# 9        Moderna: Sovereign Nation Supplement Project
# 10                  Janssen: weekly allocation dose 1
# 11  Janssen: receive dose 1 and dose 2 simultaneously
# 12       Janssen: Sovereign Nation Supplement Project
#
#                                                source                    file  \
# 0   https://data.cdc.gov/Vaccinations/COVID-19-Vac...  vaccine_allocation.csv
# 1   https://data.cdc.gov/Vaccinations/COVID-19-Vac...  vaccine_allocation.csv
# 2   https://data.cdc.gov/Vaccinations/COVID-19-Vac...  vaccine_allocation.csv
# 3   https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 4   https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 5   https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 6   https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 7   https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 8   https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 9   https://covid.cdc.gov/covid-data-tracker/#vacc...  vaccine_allocation.csv
# 10  https://data.cdc.gov/Vaccinations/COVID-19-Vac...  vaccine_allocation.csv
# 11  https://data.cdc.gov/Vaccinations/COVID-19-Vac...  vaccine_allocation.csv
# 12  https://data.cdc.gov/Vaccinations/COVID-19-Vac...  vaccine_allocation.csv
#
#     start column  end column start date  end date
# 0              4           4         -1        -1
# 1              5          31   20201214  20210614
# 2             32          58   20201214  20210614
# 3             59          85   20201214  20210614
# 4             86         112   20201214  20210614
# 5            113         139   20201214  20210614
# 6            140         165   20201221  20210614
# 7            166         191   20201221  20210614
# 8            192         217   20201221  20210614
# 9            218         243   20201221  20210614
# 10           244         251   20210301  20210510
# 11           252         259   20210301  20210510
# 12           260         267   20210301  20210510

# %% [markdown]
# # Dictionary for APM ColorOfCoronavirus

# %%
base_apm = base.loc[base["file"] == "ApmColorOfCoronavirus.csv"]
base_apm
# Out:
#               variable name  \
# 217                  stfips
# 218                  stabbr
# 219                  stname
# 220              total_2018
# 221           hispanic_2018
# 222            nhwhite_2018
# 223            nhblack_2018
# 224            nhasian_2018
# 225   totalDeathBy_yyyymmdd
# 226     whiteDeath_yyyymmdd
# 227     blackDeath_yyyymmdd
# 228  hispanicDeath_yyyymmdd
# 229     asianDeath_yyyymmdd
#
#                                                  label  \
# 217                                    State FIPS code
# 218                                 State abbreviation
# 219                                         State name
# 220                           Total population in 2018
# 221                        Hispanic pooulation in 2018
# 222              Non-Hispanic White population in 2018
# 223              Non-Hispanic Black population in 2018
# 224              Non-Hispanic Asian population in 2018
# 225              Cumulative total covid-19 death count
# 226  Cumulative covid-19 death count for non-Hispan...
# 227  Cumulative covid-19 death count for non-Hispan...
# 228       Cumulative covid-19 death count for Hispanic
# 229  Cumulative covid-19 death count for non-Hispan...
#
#                                                 source  \
# 217  https://www.apmresearchlab.org/covid/deaths-by...
# 218  https://www.apmresearchlab.org/covid/deaths-by...
# 219  https://www.apmresearchlab.org/covid/deaths-by...
# 220  https://www.apmresearchlab.org/covid/deaths-by...
# 221  https://www.apmresearchlab.org/covid/deaths-by...
# 222  https://www.apmresearchlab.org/covid/deaths-by...
# 223  https://www.apmresearchlab.org/covid/deaths-by...
# 224  https://www.apmresearchlab.org/covid/deaths-by...
# 225  https://www.apmresearchlab.org/covid/deaths-by...
# 226  https://www.apmresearchlab.org/covid/deaths-by...
# 227  https://www.apmresearchlab.org/covid/deaths-by...
# 228  https://www.apmresearchlab.org/covid/deaths-by...
# 229  https://www.apmresearchlab.org/covid/deaths-by...
#
#                           file
# 217  ApmColorOfCoronavirus.csv
# 218  ApmColorOfCoronavirus.csv
# 219  ApmColorOfCoronavirus.csv
# 220  ApmColorOfCoronavirus.csv
# 221  ApmColorOfCoronavirus.csv
# 222  ApmColorOfCoronavirus.csv
# 223  ApmColorOfCoronavirus.csv
# 224  ApmColorOfCoronavirus.csv
# 225  ApmColorOfCoronavirus.csv
# 226  ApmColorOfCoronavirus.csv
# 227  ApmColorOfCoronavirus.csv
# 228  ApmColorOfCoronavirus.csv
# 229  ApmColorOfCoronavirus.csv

# %%
df = pd.read_csv("../Pandemic/ApmColorOfCoronavirus.csv")

d = {'variable name':[] , 'start column': [], 'end column':[], 'start date':[], 'end date': []}

temp_base = base_apm.copy().reset_index(drop = True)
for i in range(temp_base.shape[0]):
    d['variable name'].append(temp_base.loc[i, 'variable name'])
    temp_var = temp_base.loc[i, 'variable name'].replace('_yyyymmdd', '')
    temp_id = [i for i, s in enumerate(df.columns) if temp_var in s]
    if temp_var not in list(base_apm.iloc[0:8, 0]):
        temp_date = [re.findall('20[\d]+', x)[0] for x in df.columns[temp_id]]
    if len(temp_id) > 1:
        d['start column'].append(temp_id[0] + 1)
        d['end column'].append(temp_id[-1] + 1)
        d['start date'].append(temp_date[0])
        d['end date'].append(temp_date[-1])
    else:
        if len(temp_id) == 1:
            d['start column'].append(temp_id[0] + 1)
            d['end column'].append(temp_id[0] + 1)
        else:
            d['start column'].append(-1)
            d['end column'].append(-1)
        d['start date'].append(-1)
        d['end date'].append(-1)

dictionary_apm = pd.DataFrame(d)
dictionary_apm
# Out:
#              variable name  start column  end column start date  end date
# 0                   stfips             1           1         -1        -1
# 1                   stabbr             2           2         -1        -1
# 2                   stname             3           3         -1        -1
# 3               total_2018             4           4         -1        -1
# 4            hispanic_2018             5           5         -1        -1
# 5             nhwhite_2018             6           6         -1        -1
# 6             nhblack_2018             7           7         -1        -1
# 7             nhasian_2018             8           8         -1        -1
# 8    totalDeathBy_yyyymmdd             9          28   20200609  20210302
# 9      whiteDeath_yyyymmdd            29          48   20200609  20210302
# 10     blackDeath_yyyymmdd            49          68   20200609  20210302
# 11  hispanicDeath_yyyymmdd            69          88   20200609  20210302
# 12     asianDeath_yyyymmdd            89         108   20200609  20210302

# %%
dictionary_apm = pd.merge(base_apm, dictionary_apm, on="variable name")
dictionary_apm
# Out:
#              variable name                                              label  \
# 0                   stfips                                    State FIPS code
# 1                   stabbr                                 State abbreviation
# 2                   stname                                         State name
# 3               total_2018                           Total population in 2018
# 4            hispanic_2018                        Hispanic pooulation in 2018
# 5             nhwhite_2018              Non-Hispanic White population in 2018
# 6             nhblack_2018              Non-Hispanic Black population in 2018
# 7             nhasian_2018              Non-Hispanic Asian population in 2018
# 8    totalDeathBy_yyyymmdd              Cumulative total covid-19 death count
# 9      whiteDeath_yyyymmdd  Cumulative covid-19 death count for non-Hispan...
# 10     blackDeath_yyyymmdd  Cumulative covid-19 death count for non-Hispan...
# 11  hispanicDeath_yyyymmdd       Cumulative covid-19 death count for Hispanic
# 12     asianDeath_yyyymmdd  Cumulative covid-19 death count for non-Hispan...
#
#                                                source  \
# 0   https://www.apmresearchlab.org/covid/deaths-by...
# 1   https://www.apmresearchlab.org/covid/deaths-by...
# 2   https://www.apmresearchlab.org/covid/deaths-by...
# 3   https://www.apmresearchlab.org/covid/deaths-by...
# 4   https://www.apmresearchlab.org/covid/deaths-by...
# 5   https://www.apmresearchlab.org/covid/deaths-by...
# 6   https://www.apmresearchlab.org/covid/deaths-by...
# 7   https://www.apmresearchlab.org/covid/deaths-by...
# 8   https://www.apmresearchlab.org/covid/deaths-by...
# 9   https://www.apmresearchlab.org/covid/deaths-by...
# 10  https://www.apmresearchlab.org/covid/deaths-by...
# 11  https://www.apmresearchlab.org/covid/deaths-by...
# 12  https://www.apmresearchlab.org/covid/deaths-by...
#
#                          file  start column  end column start date  end date
# 0   ApmColorOfCoronavirus.csv             1           1         -1        -1
# 1   ApmColorOfCoronavirus.csv             2           2         -1        -1
# 2   ApmColorOfCoronavirus.csv             3           3         -1        -1
# 3   ApmColorOfCoronavirus.csv             4           4         -1        -1
# 4   ApmColorOfCoronavirus.csv             5           5         -1        -1
# 5   ApmColorOfCoronavirus.csv             6           6         -1        -1
# 6   ApmColorOfCoronavirus.csv             7           7         -1        -1
# 7   ApmColorOfCoronavirus.csv             8           8         -1        -1
# 8   ApmColorOfCoronavirus.csv             9          28   20200609  20210302
# 9   ApmColorOfCoronavirus.csv            29          48   20200609  20210302
# 10  ApmColorOfCoronavirus.csv            49          68   20200609  20210302
# 11  ApmColorOfCoronavirus.csv            69          88   20200609  20210302
# 12  ApmColorOfCoronavirus.csv            89         108   20200609  20210302

# %% [markdown]
# ## Concatenate the dictionaries

# %%
dictionary = pd.concat([dictionary_casesAndDeaths, dictionary_mobility, dictionary_medical, dictionary_policy, 
                        dictionary_vaccine, dictionary_apm], sort=False)
dictionary.to_csv("../Pandemic/pandemic_dictionary.csv", index = False)

# %%
dictionary
# Out:
#              variable name                                              label  \
# 0                   stfips                                         State name
# 1                   stname                                    State FIPS code
# 2                  ctyfips                                        County name
# 3                  ctyname                                   County FIPS code
# 4                   scfips                          FIPS code of state-county
# ..                     ...                                                ...
# 8    totalDeathBy_yyyymmdd              Cumulative total covid-19 death count
# 9      whiteDeath_yyyymmdd  Cumulative covid-19 death count for non-Hispan...
# 10     blackDeath_yyyymmdd  Cumulative covid-19 death count for non-Hispan...
# 11  hispanicDeath_yyyymmdd       Cumulative covid-19 death count for Hispanic
# 12     asianDeath_yyyymmdd  Cumulative covid-19 death count for non-Hispan...
#
#                                                source  \
# 0   https://www.census.gov/geographies/reference-f...
# 1   https://www.census.gov/geographies/reference-f...
# 2   https://www.census.gov/geographies/reference-f...
# 3   https://www.census.gov/geographies/reference-f...
# 4   https://www.census.gov/geographies/reference-f...
# ..                                                ...
# 8   https://www.apmresearchlab.org/covid/deaths-by...
# 9   https://www.apmresearchlab.org/covid/deaths-by...
# 10  https://www.apmresearchlab.org/covid/deaths-by...
# 11  https://www.apmresearchlab.org/covid/deaths-by...
# 12  https://www.apmresearchlab.org/covid/deaths-by...
#
#                          file  start column  end column start date  end date
# 0          casesAndDeaths.csv             1           1         -1        -1
# 1          casesAndDeaths.csv             2           2         -1        -1
# 2          casesAndDeaths.csv             3           3         -1        -1
# 3          casesAndDeaths.csv             4           4         -1        -1
# 4          casesAndDeaths.csv             5           5         -1        -1
# ..                        ...           ...         ...        ...       ...
# 8   ApmColorOfCoronavirus.csv             9          28   20200609  20210302
# 9   ApmColorOfCoronavirus.csv            29          48   20200609  20210302
# 10  ApmColorOfCoronavirus.csv            49          68   20200609  20210302
# 11  ApmColorOfCoronavirus.csv            69          88   20200609  20210302
# 12  ApmColorOfCoronavirus.csv            89         108   20200609  20210302
#
# [190 rows x 8 columns]
