# %% [markdown]
# # Policy Data: Updated on 03/14/2021
#
# This contains data on policy variable from:
# 1. Govex restrictions data (JHU_US_MAP)
# 2. Boston University

# %%
import pandas as pd
from datetime import datetime
import requests

# %%
state_county_fips = pd.read_csv('~/Documents/GitHub/COVID_DataHub/Pandemic/fips/state_county_fips.csv')
state_county_fips
# Out:
#       stfips  ctyfips       stname              ctyname   fips
# 0          1        1      Alabama       Autauga County   1001
# 1          1        3      Alabama       Baldwin County   1003
# 2          1        5      Alabama       Barbour County   1005
# 3          1        7      Alabama          Bibb County   1007
# 4          1        9      Alabama        Blount County   1009
# ...      ...      ...          ...                  ...    ...
# 3215      72      145  Puerto Rico  Vega Baja Municipio  72145
# 3216      72      147  Puerto Rico    Vieques Municipio  72147
# 3217      72      149  Puerto Rico   Villalba Municipio  72149
# 3218      72      151  Puerto Rico    Yabucoa Municipio  72151
# 3219      72      153  Puerto Rico      Yauco Municipio  72153
#
# [3220 rows x 5 columns]

# %%
state_territory_fips = pd.read_csv('~/Documents/GitHub/COVID_DataHub/Pandemic/fips/state_territory_fips.csv')
state_territory_fips
# Out:
#     stfips stabbr                       stname
# 0        1     AL                      Alabama
# 1        2     AK                       Alaska
# 2        4     AZ                      Arizona
# 3        5     AR                     Arkansas
# 4        6     CA                   California
# 5        8     CO                     Colorado
# 6        9     CT                  Connecticut
# 7       10     DE                     Delaware
# 8       11     DC         District of Columbia
# 9       12     FL                      Florida
# 10      13     GA                      Georgia
# 11      15     HI                       Hawaii
# 12      16     ID                        Idaho
# 13      17     IL                     Illinois
# 14      18     IN                      Indiana
# 15      19     IA                         Iowa
# 16      20     KS                       Kansas
# 17      21     KY                     Kentucky
# 18      22     LA                    Louisiana
# ...

# %% [markdown]
# ## GOVEX data

# %%
govex = pd.read_csv("https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/restrictions_policies_detailed.csv")
govex.rename(columns={"State code GEOID":"stfips", 'State code STUSPS': 'stabbr', 'State': 'stname'}, inplace=True)

# %%
govex
# Out:
#             stname  stfips stabbr  \
# 0          Alabama       1     AL
# 1           Alaska       2     AK
# 2          Arizona       4     AZ
# 3         Arkansas       5     AR
# 4       California       6     CA
# 5         Colorado       8     CO
# 6      Connecticut       9     CT
# 7         Delaware      10     DE
# 8          Florida      12     FL
# 9          Georgia      13     GA
# 10          Hawaii      15     HI
# 11           Idaho      16     ID
# 12        Illinois      17     IL
# 13         Indiana      18     IN
# 14            Iowa      19     IA
# 15          Kansas      20     KS
# 16        Kentucky      21     KY
# 17       Louisiana      22     LA
# 18           Maine      23     ME
# 19        Maryland      24     MD
# 20   Massachusetts      25     MA
# 21        Michigan      26     MI
# 22       Minnesota      27     MN
# 23     Mississippi      28     MS
# 24        Missouri      29     MO
# 25         Montana      30     MT
# ...

# %% [markdown]
# ## BU data

# %%
bu = pd.read_csv("~/Documents/HPC_datahub/Raw data/COVID-19 US state policy database 3_10_2021.csv", skiprows=[0, 2, 3, 4], 
                 engine='python')
bu = bu.iloc[:51, :]
bu.rename(columns={'State':'stname', 'State Abbreviation':'stabbr', 'FIPS Code':'stfips'}, inplace=True)
bu['stfips'] = bu['stfips'].astype('int')
bu
# Out:
#                   stname stabbr  stfips State of emergency  \
# 0                Alabama     AL       1            3/13/20
# 1                 Alaska     AK       2            3/11/20
# 2                Arizona     AZ       4            3/11/20
# 3               Arkansas     AR       5            3/11/20
# 4             California     CA       6             3/4/20
# 5               Colorado     CO       8            3/11/20
# 6            Connecticut     CT       9            3/10/20
# 7               Delaware     DE      10            3/13/20
# 8   District of Columbia     DC      11            3/11/20
# 9                Florida     FL      12             3/9/20
# 10               Georgia     GA      13            3/14/20
# 11                Hawaii     HI      15             3/4/20
# 12                 Idaho     ID      16            3/13/20
# 13              Illinois     IL      17             3/9/20
# 14               Indiana     IN      18             3/6/20
# ...

# %%
policy = govex.merge(bu, on = ['stname', 'stfips', 'stabbr'])
policy.to_csv("../Pandemic/policy.csv", index = False)

# %%
policy.shape
# Out:
# (50, 222)

# %% [markdown]
# ## Previous code, don't run

# %%
# importing fips data. and rearranging the columns
#continent_fips = pd.read_excel("~/Documents/HPC_datahub/Raw data/fips.xlsx")
#continent_fips = continent_fips.iloc[:, [1, 3, 2, 4, 5]]

# Convert the 'integers' to integers in fips file.
#for i in range(continent_fips.shape[0]):
#    if continent_fips.iloc[i, 4] != 'unknown':
#        continent_fips.iloc[i, 4] = int(continent_fips.iloc[i, 4])
#        continent_fips.iloc[i, 2] = int(continent_fips.iloc[i, 2])

#continent_fips = continent_fips.drop(continent_fips[continent_fips.fips == 0].index)
#continent_fips = continent_fips.drop(continent_fips[continent_fips.fips == "unknown"].index)
#continent_fips.iloc[3142]
#continent_fips = continent_fips.reset_index(drop=True)
#continent_fips = continent_fips[0:3142]
#continent_fips
# Out:
#       stfips   stname ctyfips            ctyname   fips
# 0          1  Alabama       1     Autauga County   1001
# 1          1  Alabama       3     Baldwin County   1003
# 2          1  Alabama       5     Barbour County   1005
# 3          1  Alabama       7        Bibb County   1007
# 4          1  Alabama       9      Blount County   1009
# ...      ...      ...     ...                ...    ...
# 3137      56  Wyoming      37  Sweetwater County  56037
# 3138      56  Wyoming      39       Teton County  56039
# 3139      56  Wyoming      41       Uinta County  56041
# 3140      56  Wyoming      43    Washakie County  56043
# 3141      56  Wyoming      45      Weston County  56045
#
# [3142 rows x 5 columns]

# %%
#us_fips = pd.read_csv('~/Documents/HPC_datahub/Raw data/state_territory_fips.txt', sep = '|')
#us_fips.columns = ['stfips', 'state', 'stname', 'statens']
#us_fips = us_fips.drop('statens', axis = 1)
#us_fips
# Out:
#     stfips state                       stname
# 0        1    AL                      Alabama
# 1        2    AK                       Alaska
# 2        4    AZ                      Arizona
# 3        5    AR                     Arkansas
# 4        6    CA                   California
# 5        8    CO                     Colorado
# 6        9    CT                  Connecticut
# 7       10    DE                     Delaware
# 8       11    DC         District of Columbia
# 9       12    FL                      Florida
# 10      13    GA                      Georgia
# 11      15    HI                       Hawaii
# 12      16    ID                        Idaho
# 13      17    IL                     Illinois
# 14      18    IN                      Indiana
# 15      19    IA                         Iowa
# 16      20    KS                       Kansas
# 17      21    KY                     Kentucky
# 18      22    LA                    Louisiana
# ...

# %%
#print(bu.iloc[:, 112:149].columns) # check redundant columns to delete
#bu = bu.iloc[:, [i for i in range(0, 112)]+[j for j in range(149, bu.shape[1])]]
#bu.shape
# Out:
# Index(['Reopened ACA enrollment using a special enrollment period',
#        'State previously allowed audio-only telehealth',
#        'Allow audio-only telehealth',
#        'Allow/expand Medicaid telehealth coverage',
#        'State had CHIP premium non-payment lock-out period as of January 2019',
#        'Suspend CHIP premium non-payment lock-outs',
#        'Report COVID-19 testing by race/ethnicity',
#        'Report COVID-19 cases by race/ethnicity',
#        'Report COVID-19 hospitalizations by race',
#        'Report COVID-19 deaths by race/ethnicity',
#        'Report COVID-19 vaccinations by race/ethnicity',
#        'Report Indigenous COVID-19 testing',
#        'Report Indigenous COVID-19 cases',
#        'Report Indigenous COVID-19 hospitalizations',
#        'Report Indigenous COVID-19 deaths',
#        'Report Indigenous COVID-19 vaccinations',
#        'Stopped personal visitation in state prisons',
#        'Stopped in-person attorney visits in state prisons',
# ...
